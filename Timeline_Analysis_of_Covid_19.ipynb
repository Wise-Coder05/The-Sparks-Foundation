# %% [markdown]
# # Task - 7
# ### Name : **Neavil Porus A**

# %% [markdown]
# # Title : **Timeline analysis : Covid 19**

# %% [markdown]
# # Import library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import pylab as pl
# %matplotlib inline
sns.set()

# %% [markdown]
# # Loading the Dataset

# %%
df = pd.read_csv(r'owid-covid-data.csv')

# %%
#print first five row
df.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.511
# 1      AFG      Asia  ...           64.83                   0.511
# 2      AFG      Asia  ...           64.83                   0.511
# 3      AFG      Asia  ...           64.83                   0.511
# 4      AFG      Asia  ...           64.83                   0.511
#
# [5 rows x 59 columns]

# %%
#print last five row
df.tail()
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 70019      ZWE    Africa  ...           61.49                   0.571
# 70020      ZWE    Africa  ...           61.49                   0.571
# 70021      ZWE    Africa  ...           61.49                   0.571
# 70022      ZWE    Africa  ...           61.49                   0.571
# 70023      ZWE    Africa  ...           61.49                   0.571
#
# [5 rows x 59 columns]

# %%
#print random five row
df.sample(5)
# Out:
#       iso_code      continent  ... life_expectancy human_development_index
# 13079      CHL  South America  ...           80.18                   0.851
# 3940       AUS        Oceania  ...           83.44                   0.944
# 58457      KOR           Asia  ...           83.03                   0.916
# 16398      CYP         Europe  ...           80.98                   0.887
# 18661      ECU  South America  ...           77.01                   0.759
#
# [5 rows x 59 columns]

# %%
print(df.info())             #full summary of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70024 entries, 0 to 70023
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               70024 non-null  object
#  1   continent                              66534 non-null  object
#  2   location                               70024 non-null  object
#  3   date                                   70024 non-null  object
#  4   total_cases                            69142 non-null  float64
#  5   new_cases                              69140 non-null  float64
#  6   new_cases_smoothed                     68139 non-null  float64
#  7   total_deaths                           60162 non-null  float64
#  8   new_deaths                             60320 non-null  float64
#  9   new_deaths_smoothed                    68139 non-null  float64
#  10  total_cases_per_million                68763 non-null  float64
#  11  new_cases_per_million                  68761 non-null  float64
#  12  new_cases_smoothed_per_million         67765 non-null  float64
#  13  total_deaths_per_million               59796 non-null  float64
#  14  new_deaths_per_million                 59954 non-null  float64
#  15  new_deaths_smoothed_per_million        67765 non-null  float64
#  16  reproduction_rate                      56195 non-null  float64
#  17  icu_patients                           7473 non-null   float64
#  18  icu_patients_per_million               7473 non-null   float64
#  19  hosp_patients                          8882 non-null   float64
#  20  hosp_patients_per_million              8882 non-null   float64
#  21  weekly_icu_admissions                  702 non-null    float64
#  22  weekly_icu_admissions_per_million      702 non-null    float64
#  23  weekly_hosp_admissions                 1155 non-null   float64
#  24  weekly_hosp_admissions_per_million     1155 non-null   float64
#  25  new_tests                              31713 non-null  float64
#  26  total_tests                            31504 non-null  float64
#  27  total_tests_per_thousand               31504 non-null  float64
#  28  new_tests_per_thousand                 31713 non-null  float64
#  29  new_tests_smoothed                     35866 non-null  float64
#  30  new_tests_smoothed_per_thousand        35866 non-null  float64
#  31  positive_rate                          34443 non-null  float64
#  32  tests_per_case                         33924 non-null  float64
#  33  tests_units                            37138 non-null  object
#  34  total_vaccinations                     2287 non-null   float64
#  35  people_vaccinated                      1886 non-null   float64
#  36  people_fully_vaccinated                1205 non-null   float64
#  37  new_vaccinations                       1935 non-null   float64
#  38  new_vaccinations_smoothed              3274 non-null   float64
#  39  total_vaccinations_per_hundred         2287 non-null   float64
#  40  people_vaccinated_per_hundred          1886 non-null   float64
#  41  people_fully_vaccinated_per_hundred    1205 non-null   float64
#  42  new_vaccinations_smoothed_per_million  3274 non-null   float64
#  43  stringency_index                       59808 non-null  float64
#  44  population                             69636 non-null  float64
#  45  population_density                     65462 non-null  float64
#  46  median_age                             63763 non-null  float64
#  47  aged_65_older                          63027 non-null  float64
#  48  aged_70_older                          63403 non-null  float64
#  49  gdp_per_capita                         63918 non-null  float64
#  50  extreme_poverty                        43674 non-null  float64
#  51  cardiovasc_death_rate                  64521 non-null  float64
#  52  diabetes_prevalence                    65316 non-null  float64
#  53  female_smokers                         50809 non-null  float64
#  54  male_smokers                           50112 non-null  float64
#  55  handwashing_facilities                 32357 non-null  float64
#  56  hospital_beds_per_thousand             59148 non-null  float64
#  57  life_expectancy                        66538 non-null  float64
#  58  human_development_index                64500 non-null  float64
# dtypes: float64(54), object(5)
# memory usage: 31.5+ MB
# None

# %%
print(df.describe())    #statistical details of the dataset
# Out:
#         total_cases      new_cases  ...  life_expectancy  human_development_index
# count  6.914200e+04   69140.000000  ...     66538.000000             64500.000000
# mean   5.757381e+05    5080.088588  ...        73.139533                 0.728251
# std    4.075775e+06   32219.329559  ...         7.550024                 0.150145
# min    1.000000e+00  -46076.000000  ...        53.280000                 0.394000
# 25%    6.710000e+02       1.000000  ...        67.440000                 0.606000
# 50%    7.150000e+03      56.000000  ...        74.530000                 0.748000
# 75%    7.819525e+04     642.000000  ...        78.730000                 0.848000
# max    1.107250e+08  879905.000000  ...        86.750000                 0.957000
#
# [8 rows x 54 columns]

# %%
print(df.shape)      #shape of dataset
# Out:
# (70024, 59)

# %%
duplicate_rows_df = df[df.duplicated()]

print("Number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (0, 59)

# %%
df.count() #Used to count the number of rows
# Out:
# iso_code                                 70024
# continent                                66534
# location                                 70024
# date                                     70024
# total_cases                              69142
# new_cases                                69140
# new_cases_smoothed                       68139
# total_deaths                             60162
# new_deaths                               60320
# new_deaths_smoothed                      68139
# total_cases_per_million                  68763
# new_cases_per_million                    68761
# new_cases_smoothed_per_million           67765
# total_deaths_per_million                 59796
# new_deaths_per_million                   59954
# new_deaths_smoothed_per_million          67765
# reproduction_rate                        56195
# icu_patients                              7473
# icu_patients_per_million                  7473
# hosp_patients                             8882
# hosp_patients_per_million                 8882
# weekly_icu_admissions                      702
# weekly_icu_admissions_per_million          702
# weekly_hosp_admissions                    1155
# weekly_hosp_admissions_per_million        1155
# new_tests                                31713
# total_tests                              31504
# total_tests_per_thousand                 31504
# new_tests_per_thousand                   31713
# new_tests_smoothed                       35866
# new_tests_smoothed_per_thousand          35866
# positive_rate                            34443
# tests_per_case                           33924
# tests_units                              37138
# total_vaccinations                        2287
# people_vaccinated                         1886
# people_fully_vaccinated                   1205
# new_vaccinations                          1935
# new_vaccinations_smoothed                 3274
# total_vaccinations_per_hundred            2287
# people_vaccinated_per_hundred             1886
# people_fully_vaccinated_per_hundred       1205
# new_vaccinations_smoothed_per_million     3274
# stringency_index                         59808
# population                               69636
# population_density                       65462
# median_age                               63763
# aged_65_older                            63027
# aged_70_older                            63403
# gdp_per_capita                           63918
# extreme_poverty                          43674
# cardiovasc_death_rate                    64521
# diabetes_prevalence                      65316
# female_smokers                           50809
# male_smokers                             50112
# handwashing_facilities                   32357
# hospital_beds_per_thousand               59148
# life_expectancy                          66538
# human_development_index                  64500
# dtype: int64

# %%
df.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 3490
# location                                     0
# date                                         0
# total_cases                                882
# new_cases                                  884
# new_cases_smoothed                        1885
# total_deaths                              9862
# new_deaths                                9704
# new_deaths_smoothed                       1885
# total_cases_per_million                   1261
# new_cases_per_million                     1263
# new_cases_smoothed_per_million            2259
# total_deaths_per_million                 10228
# new_deaths_per_million                   10070
# new_deaths_smoothed_per_million           2259
# reproduction_rate                        13829
# icu_patients                             62551
# icu_patients_per_million                 62551
# hosp_patients                            61142
# hosp_patients_per_million                61142
# weekly_icu_admissions                    69322
# weekly_icu_admissions_per_million        69322
# weekly_hosp_admissions                   68869
# weekly_hosp_admissions_per_million       68869
# new_tests                                38311
# total_tests                              38520
# total_tests_per_thousand                 38520
# new_tests_per_thousand                   38311
# new_tests_smoothed                       34158
# new_tests_smoothed_per_thousand          34158
# positive_rate                            35581
# tests_per_case                           36100
# tests_units                              32886
# total_vaccinations                       67737
# people_vaccinated                        68138
# people_fully_vaccinated                  68819
# new_vaccinations                         68089
# new_vaccinations_smoothed                66750
# total_vaccinations_per_hundred           67737
# people_vaccinated_per_hundred            68138
# people_fully_vaccinated_per_hundred      68819
# new_vaccinations_smoothed_per_million    66750
# stringency_index                         10216
# population                                 388
# population_density                        4562
# median_age                                6261
# aged_65_older                             6997
# aged_70_older                             6621
# gdp_per_capita                            6106
# extreme_poverty                          26350
# cardiovasc_death_rate                     5503
# diabetes_prevalence                       4708
# female_smokers                           19215
# male_smokers                             19912
# handwashing_facilities                   37667
# hospital_beds_per_thousand               10876
# life_expectancy                           3486
# human_development_index                   5524
# dtype: int64

# %%
df1=df[["date","total_cases","new_cases","total_deaths","new_tests","total_tests"]]
df1.head()
# Out:
#          date  total_cases  new_cases  total_deaths  new_tests  total_tests
# 0  2020-02-24          1.0        1.0           NaN        NaN          NaN
# 1  2020-02-25          1.0        0.0           NaN        NaN          NaN
# 2  2020-02-26          1.0        0.0           NaN        NaN          NaN
# 3  2020-02-27          1.0        0.0           NaN        NaN          NaN
# 4  2020-02-28          1.0        0.0           NaN        NaN          NaN

# %%
df1.mean()
# Out:
# total_cases     5.757381e+05
# new_cases       5.080089e+03
# total_deaths    1.762907e+04
# new_tests       3.711129e+04
# total_tests     4.238308e+06
# dtype: float64

# %%
df1.cov()
# Out:
#                total_cases     new_cases  ...     new_tests   total_tests
# total_cases   1.661194e+13  1.186190e+11  ...  1.749837e+11  2.684369e+13
# new_cases     1.186190e+11  1.038085e+09  ...  1.577930e+09  1.965216e+11
# total_deaths  4.366253e+11  3.242316e+09  ...  3.640342e+09  5.239069e+11
# new_tests     1.749837e+11  1.577930e+09  ...  2.119633e+10  2.620905e+12
# total_tests   2.684369e+13  1.965216e+11  ...  2.620905e+12  3.860397e+14
#
# [5 rows x 5 columns]

# %%
df1.corr()
# Out:
#               total_cases  new_cases  total_deaths  new_tests  total_tests
# total_cases      1.000000   0.903215      0.978604   0.846228     0.959507
# new_cases        0.903215   1.000000      0.919597   0.865230     0.800078
# total_deaths     0.978604   0.919597      1.000000   0.828307     0.877204
# new_tests        0.846228   0.865230      0.828307   1.000000     0.883840
# total_tests      0.959507   0.800078      0.877204   0.883840     1.000000

# %%
df1.var()
# Out:
# total_cases     1.661194e+13
# new_cases       1.038085e+09
# total_deaths    1.045789e+10
# new_tests       2.119633e+10
# total_tests     3.860397e+14
# dtype: float64

# %%
df1.std()
# Out:
# total_cases     4.075775e+06
# new_cases       3.221933e+04
# total_deaths    1.022638e+05
# new_tests       1.455896e+05
# total_tests     1.964789e+07
# dtype: float64

# %% [markdown]
# # Proper visualization of dataset

# %%
sns.distplot(df1['total_cases'])
sns.distplot(df1['new_cases']);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1.plot(figsize = (10 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
sns.distplot(df1['total_tests'])
sns.distplot(df1['new_tests']);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1.new_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_deaths.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# # Trends and Seasonality in TimeSeries Dataset

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
new_cases = df1[['new_cases']]
new_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
sns.pairplot(df1, size=2.5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
with sns.axes_style('white'):
    sns.jointplot("new_cases", "total_cases", data=df1, kind='reg')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(df1['total_cases'], kde=False);
plt.axvline(0, color="k", linestyle="--");
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df1['new_cases'], kde=False);
plt.axvline(0, color="r", linestyle="--");
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df1['total_tests'], kde=False);
plt.axvline(0, color="r", linestyle="--");
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df1['new_tests'], kde=False);
plt.axvline(0, color="r", linestyle="--");
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
total_cases.diff().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20);

# %%
df1.total_cases.plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
total_cases=df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# # Thank you
